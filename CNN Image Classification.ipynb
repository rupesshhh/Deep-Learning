# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
(train_images, train_labels), (test_images, test_labels) = datasets.fashion_mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
model = models.Sequential([
    layers.Flatten(input_shape = (28, 28)),
    layers.Dense(128, activation = 'relu'),
    layers.Dropout(0.2),
    layers.Dense(10)
    ])
model.compile(optimizer = 'adam',
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
metrics = ['accuracy'])

# %%
history = model.fit(train_images, train_labels, epochs = 5, validation_data = (test_images, test_labels))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.5345 - accuracy: 0.8112 - val_loss: 0.4290 - val_accuracy: 0.8448
# Epoch 2/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4015 - accuracy: 0.8551 - val_loss: 0.4528 - val_accuracy: 0.8277
# Epoch 3/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3678 - accuracy: 0.8667 - val_loss: 0.3683 - val_accuracy: 0.8677
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3464 - accuracy: 0.8733 - val_loss: 0.3599 - val_accuracy: 0.8720
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3295 - accuracy: 0.8794 - val_loss: 0.3636 - val_accuracy: 0.8684

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy: ', test_acc)
# Out:
# 313/313 [==============================] - 0s 829us/step - loss: 0.3636 - accuracy: 0.8684
# Test accuracy:  0.868399977684021

# %%
plt.plot(history.history['accuracy'], label = 'accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')

plt.ylabel('Accuracy')

plt.legend(loc = 'lower right')

plt.show()
